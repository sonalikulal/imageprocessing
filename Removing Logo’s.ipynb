# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from skimage.restoration import inpaint
from skimage.transform import resize
from skimage import color
image_with_logo=plt.imread('llogo.png')
mask=np.zeros(image_with_logo.shape[:-1])
mask[50:140,50:150]=1
image_logo_removed=inpaint.inpaint_biharmonic(image_with_logo, 
mask,multichannel=True)
plt.title('image with logo')
plt.imshow(image_with_logo)
plt.show()
plt.title('image without logo')
plt.imshow(image_logo_removed)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from skimage.restoration import inpaint
from skimage.transform import resize
from skimage import color
image_with_logo=plt.imread('C:/Users/User/Downloads/logoo.png')
mask=np.zeros(image_with_logo.shape[:-1])
mask[60:190,200:400]=1
image_logo_removed=inpaint.inpaint_biharmonic(image_with_logo, 
mask,multichannel=True)
plt.title('image with logo')
plt.imshow(image_with_logo)
plt.show()
plt.title('image without logo')
plt.imshow(image_logo_removed)
plt.show()
