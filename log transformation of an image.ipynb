# %%
import numpy as np

# input a number as integer
a = int(input())

print("Natural log value of the input number is",
	np.log(a))

# If you want base of log to be set to 2
print("Log value of the number with base 2 is",
	np.log2(a))

# If you want base of log to be set to 10
print("Log value of the number with base 10 is",
	np.log10(a))
# Out:
# 5
# Natural log value of the input number is 1.6094379124341003
# Log value of the number with base 2 is 2.321928094887362
# Log value of the number with base 10 is 0.6989700043360189

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read an image
image = cv2.imread('cat.jpg')

# Apply log transformation method
c = 255 / np.log(1 + np.max(image))
log_image = c * (np.log(image + 1))

# Specify the data type so that
# float value will be converted to int
log_image = np.array(log_image, dtype = np.uint8)

# Display both images
plt.imshow(image)
plt.show()
plt.imshow(log_image)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_1532/724948907.py:10: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(image + 1))

# %%
#finding negative of an image
import cv2
import numpy as np
img=cv2.imread('cat.jpg')
print(img.dtype)
img_neg=255-img
cv2.imshow('negative_img',img_neg)
cv2.waitKey(0)
# Out:
# uint8
# -1

# %%
#block extraction from an image
from skimage.io import imshow,imread
import matplotlib.pyplot as plt
img1=imread('cat.jpg')
imshow(img1)
fig,ax=plt.subplots(1,3,figsize=(6,4),sharey=True)
ax[0].imshow(img1[:,0:150])
ax[0].set_title('first block')
ax[1].imshow(img1[400:640,200:650])
ax[1].set_title('second block')
ax[2].imshow(img1[:,600:800])
ax[2].set_title('third block')
# Out:
# Text(0.5, 1.0, 'third block')

# %%
import cv2 
#import matplotlib as plt
img=cv2.imread('1-500x250-3.jpg')
img2=cv2.imread('2-500x250-2.jpg')
add=img+img2
sub=img-img2
mul=img*img2
div=img/img2
plt.imshow(add)
plt.show()
plt.imshow(sub)
plt.show()
plt.imshow(mul)
plt.show()
plt.imshow(div)
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_1532/1703422610.py:8: RuntimeWarning: divide by zero encountered in true_divide
#   div=img/img2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
