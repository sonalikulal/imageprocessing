# %%
import skimage.io
import skimage.util
import matplotlib.pyplot as plt
a = skimage.io.imread('C:/Users/User/Downloads/cam.jpg')
print(a.shape)
# (225, 400, 3)

b = a // 1
c = a // 1
d = a//3

img = skimage.util.montage([a, b, c,d], multichannel=True)
print(img.shape)
# (450, 800, 3)

plt.imshow(m)
plt.show()
# Out:
# (194, 259, 3)
# (388, 518, 3)
